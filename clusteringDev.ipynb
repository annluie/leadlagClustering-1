# %%
import os
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from scipy.sparse import csr_matrix
from signet.cluster import Cluster
import glob

# %%
# Path to the 'Yearly' directory
data_root = "Data/CRSP/Yearly"

# %%
def load_gzipped_data(data_root):
    """
    Loads all .csv.gz daily files from Yearly/2000 through Yearly/2015.
    Extracts the date from the filename and adds it as a column.
    """
    all_files = []
    for year in range(2000, 2016):
        pattern = os.path.join(data_root, str(year), "*.csv.gz")
        files = sorted(glob.glob(pattern))
        
        for f in files:
            try:
                df_day = pd.read_csv(f, compression='gzip')
                date_str = os.path.basename(f).replace(".csv.gz", "")
                df_day["date"] = pd.to_datetime(date_str, format="%Y%m%d")
                all_files.append(df_day)
            except Exception as e:
                print(f"Skipping {f}: {e}")

    df = pd.concat(all_files, ignore_index=True)
    return df

# %%
# def compute_lookback_return_matrix(df, lookback=20):
#     """
#     Computes log-returns over a given lookback window and returns a
#     (tickers × dates) matrix.
#     """
#     df = df.copy()
#     df = df.sort_values(by=['ticker', 'date'])
#     df['log_adjclose'] = np.log(df['prevAdjClose'])
    
#     df['log_return'] = df.groupby('ticker')['log_adjclose'].transform(
#         lambda x: x - x.shift(lookback)
#     )
    
#     df = df.dropna(subset=['log_return']) ##CHECK THIS LATER
#     return df.pivot(index='ticker', columns='date', values='log_return')

##maybe do it this way instead

# %%
def build_signed_graph(R, threshold=0.3):
    """
    R: (n_assets x n_times) return matrix
    threshold: correlation cutoff for edge inclusion

    Returns: (Ap, An) positive and negative adjacency matrices
    """
    corr = R.T.corr().fillna(0)
    np.fill_diagonal(corr.values, 0)  # remove self loops

    
    Ap = csr_matrix(corr.values * (corr.values >= threshold))
    An = csr_matrix(-corr.values * (corr.values <= -threshold))

    return Ap, An

# %%
def sponge_clustering(Ap, An, k=5, tau_p=1, tau_n=1):
    """
    Perform SPONGE clustering on signed graph defined by (Ap, An)
    """
    clusterer = Cluster((Ap, An))
    labels = clusterer.SPONGE(k=k, tau_p=tau_p, tau_n=tau_n)
    return labels

# %%
# def run_sponge_pipeline(data_root, k=5, lookback=20):
#     df = load_data(data_root)
    
#     print(f"Computing log-returns with lookback = {lookback} days...")
#     R = compute_lookback_return_matrix(df, lookback=lookback)
    
#     print("Constructing signed graph...")
#     Ap, An = construct_signed_graph(R)
    
#     print("Running SPONGE clustering...")
#     labels = sponge_clustering(Ap, An, k=k)
    
#     return pd.DataFrame({'ticker': R.index, 'cluster': labels})

# %%
# if __name__ == "__main__":
#     data_root = "Data/SYearly"
#     lookback = 20
#     num_clusters = 5
#     threshold = 0.3

#     print("Loading data...")
#     df = load_gzipped_data(data_root)

#     print(f"Computing log-returns with lookback = {lookback} days...")
#     R = compute_lookback_return_matrix(df, lookback=lookback)

#     print("Building signed graph from correlation matrix...")
#     Ap, An = build_signed_graph(R, threshold=threshold)

#     print(f"Running SPONGE clustering into {num_clusters} clusters...")
#     labels = sponge_clustering(Ap, An, k=num_clusters)

#     tickers = R.index.tolist()
#     clustered = pd.DataFrame({'ticker': tickers, 'cluster': labels})
#     print(clustered.head())
# Out:
# Loading data...
# Computing log-returns with lookback = 20 days...
# /usr/local/lib/python3.9/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Building signed graph from correlation matrix...
# Running SPONGE clustering into 5 clusters...
#   ticker  cluster
# 0     AA        0
# 1    AAA        3
# 2    AAC        4
# 3    AAG        1
# 4    AAI        3

# %%
df = load_gzipped_data("Data/CRSP/Yearly")

# %%
def compute_lookback_return_matrix(df, window_dates):
    df_window = df[df['date'].isin(window_dates)].copy()
    df_window = df_window[df_window['prevAdjClose'] > 0]  # filter non-positive prices
    
    df_window = df_window.sort_values(['ticker', 'date'])
    df_window['log_adjclose'] = np.log(df_window['prevAdjClose'])
    # For each ticker, shift the log_adjclose by `lookback` days ##CHECK THIS PART OF THE CODE
    df_window['log_adjclose_shifted'] = df_window.groupby('ticker')['log_adjclose'].shift(lookback)

    #Calculate the window log return explicitly over the lookback window
    df_window['log_return'] = df_window['log_adjclose'] - df_window['log_adjclose_shifted']
    df_window = df_window.dropna(subset=['log_return'])
    
    R = df_window.pivot(index='ticker', columns='date', values='log_return')
    return R

# %%
def build_signed_graph(R, threshold=0.3):
    corr = R.T.corr().fillna(0)
    np.fill_diagonal(corr.values, 0)
    Ap = csr_matrix(corr.values * (corr.values >= threshold))
    An = csr_matrix(-corr.values * (corr.values <= -threshold))
    return Ap, An

# %%
def sponge_clustering(Ap, An, k=5, tau_p=1, tau_n=1):
    clusterer = Cluster((Ap, An))
    labels = clusterer.SPONGE(k=k, tau_p=tau_p, tau_n=tau_n)
    return labels

# %%
def run_rolling_sponge_clustering(df, lookback=20, threshold=0.3, k=5):
    df = df.sort_values('date')
    unique_dates = df['date'].drop_duplicates().sort_values().reset_index(drop=True)

    results = []

    for i in range(lookback, len(unique_dates)):
        window_dates = unique_dates[i - lookback:i]
        R = compute_lookback_return_matrix(df, window_dates)
        
        if R.shape[1] < 2:
            # Not enough data to compute correlation
            continue

        Ap, An = build_signed_graph(R, threshold=threshold)
        labels = sponge_clustering(Ap, An, k=k)

        results.append({
            'date': unique_dates[i],
            'tickers': R.index.tolist(),
            'labels': labels
        })
        print(f"Processed clustering for window ending {unique_dates[i].date()}")

        print({
            'date': unique_dates[i],
            'tickers': R.index.tolist(),
            'labels': labels
        })

    return results

# %%
#df = your_loaded_dataframe_with_all_data
results = run_rolling_sponge_clustering(df, lookback=20, threshold=0.3, k=5)
# Out:
# Processed clustering for window ending 2000-02-01
# {'date': Timestamp('2000-02-01 00:00:00'), 'tickers': ['AA', 'AAC', 'AAG', 'AAIR', 'AAM', 'AAP', 'AAS', 'AAT', 'AB', 'ABERF', 'ABF', 'ABG', 'ABK', 'ABM', 'ABMD', 'ABN', 'ABP', 'ABR', 'ABRI', 'ABS', 'ABT', 'ABX', 'ABY', 'AC', 'ACEE', 'ACF', 'ACG', 'ACI', 'ACK', 'ACL', 'ACLNF', 'ACN', 'ACO', 'ACP', 'ACR', 'ACRG', 'ACS', 'ACTN', 'ACV', 'ACX', 'ACXM', 'AD', 'ADC', 'ADECY', 'ADF', 'ADG', 'ADI', 'ADM', 'ADMS', 'ADP', 'ADPT', 'ADV', 'ADX', 'AEC', 'AED', 'AEE', 'AEG', 'AEM', 'AEOS', 'AEP', 'AER', 'AES', 'AET', 'AF', 'AFC', 'AFF', 'AFG', 'AFL', 'AFM', 'AFP', 'AFS', 'AG', 'AGA', 'AGC', 'AGE', 'AGI', 'AGL', 'AGM', 'AGN', 'AGR', 'AGS', 'AGTX', 'AGU', 'AGX', 'AGY', 'AH', 'AHC', 'AHG', 'AHI', 'AHMH', 'AHO', 'AHP', 'AHR', 'AIB', 'AIC', 'AIF', 'AIG', 'AIN', 'AIR', 'AIV', 'AIZ', 'AJG', 'AJL', 'AJX', 'AK', 'AKO', 'AKR', 'AKS', 'AL', 'ALA', 'ALB', 'ALC', 'ALEX', 'ALG', 'ALK', 'ALL', 'ALLC', 'ALLE', 'ALLY', 'ALM', 'ALN', 'ALO', 'ALR', 'ALRE', 'ALS', 'ALU', 'ALV', 'ALX', 'AM', 'AMB', 'AMC', 'AMCR', 'AMD', 'AME', 'AMF', 'AMG', 'AMH', 'AMI', 'AMK', 'AML', 'AMN', 'AMO', 'AMR', 'AMSGA', 'AMT', 'AMTD', 'AMU', 'AMZ', 'AN', 'ANET', 'ANF', 'ANFI', 'ANH', 'ANN', 'ANS', 'ANZ', 'AOC', 'AOF', 'AOG', 'AOI', 'AOL', 'AOR', 'AOS', 'AP', 'APA', 'APB', 'APC', 'APD', 'APF', 'APGR', 'APH', 'APM', 'APO', 'APR', 'APS', 'APU', 'APW', 'APX', 'APZ', 'AQM', 'ARA', 'ARB', 'ARC', 'ARE', 'ARG', 'ARGX', 'ARH', 'ARI', 'ARJ', 'ARK', 'ARMF', 'ARSD', 'ART', 'ARV', 'ARW', 'ARX', 'ASA', 'ASBC', 'ASD', 'ASF', 'ASFC', 'ASG', 'ASGN', 'ASH', 'ASI', 'ASL', 'ASN', 'ASO', 'ASP', 'ASV', 'AT', 'ATC', 'ATEC', 'ATG', 'ATHM', 'ATI', 'ATK', 'ATL', 'ATO', 'ATR', 'ATS', 'ATV', 'ATW', 'ATY', 'AU', 'AUD', 'AVA', 'AVB', 'AVD', 'AVE', 'AVI', 'AVL', 'AVP', 'AVS', 'AVT', 'AVTR', 'AVX', 'AVY', 'AVZ', 'AW', 'AWA', 'AWC', 'AWF', 'AWG', 'AWK', 'AWR', 'AXA', 'AXE', 'AXF', 'AXL', 'AXM', 'AXP', 'AXR', 'AXT', 'AYE', 'AZA', 'AZN', 'AZO', 'AZR', 'AZUR', 'AZX', 'AZZ', 'B', 'BA', 'BAB', 'BAC', 'BALT', 'BANC', 'BAP', 'BAS', 'BAT', 'BAU', 'BAX', 'BB', 'BBA', 'BBAR', 'BBC', 'BBDC', 'BBI', 'BBR', 'BBT', 'BBV', 'BBX', 'BBY', 'BC', 'BCC', 'BCE', 'BCF', 'BCM', 'BCR', 'BCS', 'BCU', 'BD', 'BDE', 'BDF', 'BDG', 'BDK', 'BDL', 'BDN', 'BDX', 'BDY', 'BE', 'BEAM', 'BEC', 'BED', 'BEL', 'BEM', 'BEN', 'BEST', 'BETA', 'BEV', 'BEZ', 'BF', 'BFAM', 'BFC', 'BFCI', 'BFD', 'BFO', 'BFR', 'BFS', 'BFT', 'BGA', 'BGC', 'BGG', 'BGL', 'BGO', 'BGP', 'BGR', 'BGT', 'BGY', 'BH', 'BHC', 'BHE', 'BHI', 'BHP', 'BHW', 'BHY', 'BI', 'BID', 'BILL', 'BIN', 'BIO', 'BIOM', 'BIR', 'BJ', 'BJS', 'BK', 'BKC', 'BKE', 'BKF', 'BKH', 'BKI', 'BKLY', 'BKN', 'BKR', 'BKS', 'BKT', 'BLC', 'BLD', 'BLE', 'BLK', 'BLL', 'BLN', 'BLS', 'BLT', 'BLU', 'BLX', 'BMC', 'BMCS', 'BMG', 'BMHC', 'BMI', 'BMN', 'BMO', 'BMS', 'BMT', 'BMY', 'BN', 'BNA', 'BNE', 'BNG', 'BNI', 'BNL', 'BNO', 'BNS', 'BNT', 'BOA', 'BOG', 'BOH', 'BOL', 'BOOT', 'BOP', 'BOR', 'BOS', 'BOW', 'BOX', 'BOY', 'BPA', 'BPC', 'BPL', 'BPO', 'BPP', 'BPRX', 'BPT', 'BQT', 'BR', 'BRC', 'BRE', 'BRF', 'BRK', 'BRL', 'BRM', 'BRO', 'BRR', 'BRS', 'BRT', 'BRW', 'BRY', 'BS', 'BSB', 'BSC', 'BSD', 'BSH', 'BSI', 'BSP', 'BSTI', 'BSX', 'BSY', 'BSYS', 'BTF', 'BTH', 'BTI', 'BTM', 'BTN', 'BTO', 'BTR', 'BTT', 'BTY', 'BTZ', 'BUD', 'BUR', 'BVC', 'BVF', 'BVN', 'BW', 'BWA', 'BWC', 'BWE', 'BWG', 'BWP', 'BWS', 'BXG', 'BXL', 'BXM', 'BXP', 'BXS', 'BXT', 'BY', 'BYD', 'BYH', 'BZ', 'BZF', 'BZH', 'BZL', 'C', 'CA', 'CAA', 'CAB', 'CACI', 'CACOA', 'CADE', 'CAE', 'CAF', 'CAG', 'CAH', 'CAL', 'CAM', 'CAN', 'CANNY', 'CAO', 'CAP', 'CAR', 'CARL', 'CARN', 'CARS', 'CAS', 'CASC', 'CAT', 'CAV', 'CB', 'CBA', 'CBC', 'CBCL', 'CBE', 'CBG', 'CBH', 'CBI', 'CBIZ', 'CBK', 'CBL', 'CBLI', 'CBM', 'CBR', 'CBS', 'CBT', 'CBU', 'CBZ', 'CC', 'CCB', 'CCC', 'CCE', 'CCG', 'CCH', 'CCJ', 'CCK', 'CCL', 'CCN', 'CCOM', 'CCR', 'CCS', 'CCU', 'CD', 'CDA', 'CDB', 'CDC', 'CDCY', 'CDD', 'CDE', 'CDF', 'CDI', 'CDIS', 'CDL', 'CDN', 'CDO', 'CDP', 'CDT', 'CDX', 'CEA', 'CEC', 'CEE', 'CEFT', 'CEG', 'CEI', 'CEL', 'CEM', 'CEN', 'CF', 'CFA', 'CFB', 'CFCM', 'CFD', 'CFI', 'CFK', 'CFN', 'CFR', 'CFS', 'CFX', 'CG', 'CGA ...
# Processed clustering for window ending 2000-02-02
# {'date': Timestamp('2000-02-02 00:00:00'), 'tickers': ['AA', 'AAC', 'AAG', 'AAIR', 'AAM', 'AAP', 'AAS', 'AAT', 'AB', 'ABERF', 'ABF', 'ABG', 'ABK', 'ABM', 'ABMD', 'ABN', 'ABP', 'ABR', 'ABRI', 'ABS', 'ABT', 'ABX', 'ABY', 'AC', 'ACEE', 'ACF', 'ACG', 'ACI', 'ACK', 'ACL', 'ACLNF', 'ACN', 'ACO', 'ACP', 'ACR', 'ACRG', 'ACS', 'ACTN', 'ACV', 'ACX', 'ACXM', 'AD', 'ADC', 'ADECY', 'ADF', 'ADG', 'ADI', 'ADM', 'ADMS', 'ADP', 'ADPT', 'ADV', 'ADX', 'AEC', 'AED', 'AEE', 'AEG', 'AEM', 'AEOS', 'AEP', 'AER', 'AES', 'AET', 'AF', 'AFC', 'AFF', 'AFG', 'AFL', 'AFM', 'AFP', 'AFS', 'AG', 'AGA', 'AGC', 'AGE', 'AGI', 'AGL', 'AGM', 'AGN', 'AGR', 'AGS', 'AGTX', 'AGU', 'AGX', 'AGY', 'AH', 'AHC', 'AHG', 'AHI', 'AHMH', 'AHO', 'AHP', 'AHR', 'AIB', 'AIC', 'AIF', 'AIG', 'AIN', 'AIR', 'AIV', 'AIZ', 'AJG', 'AJL', 'AJX', 'AK', 'AKO', 'AKR', 'AKS', 'AL', 'ALA', 'ALB', 'ALC', 'ALEX', 'ALG', 'ALK', 'ALL', 'ALLC', 'ALLE', 'ALLY', 'ALM', 'ALN', 'ALO', 'ALR', 'ALRE', 'ALS', 'ALU', 'ALV', 'ALX', 'AM', 'AMB', 'AMC', 'AMCR', 'AMD', 'AME', 'AMF', 'AMG', 'AMH', 'AMI', 'AMK', 'AML', 'AMN', 'AMO', 'AMR', 'AMSGA', 'AMT', 'AMTD', 'AMU', 'AMZ', 'AN', 'ANET', 'ANF', 'ANFI', 'ANH', 'ANN', 'ANS', 'ANZ', 'AOC', 'AOF', 'AOG', 'AOI', 'AOL', 'AOR', 'AOS', 'AP', 'APA', 'APB', 'APC', 'APD', 'APF', 'APGR', 'APH', 'APL', 'APM', 'APO', 'APR', 'APS', 'APU', 'APW', 'APX', 'APZ', 'AQM', 'ARA', 'ARB', 'ARC', 'ARE', 'ARG', 'ARGX', 'ARH', 'ARI', 'ARJ', 'ARK', 'ARMF', 'ARSD', 'ART', 'ARV', 'ARW', 'ARX', 'ASA', 'ASBC', 'ASD', 'ASF', 'ASFC', 'ASG', 'ASGN', 'ASH', 'ASI', 'ASL', 'ASN', 'ASO', 'ASP', 'ASV', 'AT', 'ATC', 'ATEC', 'ATG', 'ATHM', 'ATI', 'ATK', 'ATL', 'ATO', 'ATR', 'ATS', 'ATV', 'ATW', 'ATY', 'AU', 'AUD', 'AVA', 'AVB', 'AVD', 'AVE', 'AVI', 'AVL', 'AVP', 'AVS', 'AVT', 'AVTR', 'AVX', 'AVY', 'AVZ', 'AW', 'AWA', 'AWF', 'AWG', 'AWK', 'AWR', 'AXA', 'AXE', 'AXF', 'AXL', 'AXM', 'AXP', 'AXR', 'AXT', 'AYE', 'AZA', 'AZN', 'AZO', 'AZR', 'AZUR', 'AZX', 'AZZ', 'B', 'BA', 'BAB', 'BAC', 'BALT', 'BANC', 'BAP', 'BAS', 'BAT', 'BAU', 'BAX', 'BB', 'BBA', 'BBAR', 'BBC', 'BBDC', 'BBI', 'BBR', 'BBT', 'BBV', 'BBX', 'BBY', 'BC', 'BCC', 'BCE', 'BCF', 'BCM', 'BCR', 'BCS', 'BCU', 'BD', 'BDE', 'BDF', 'BDG', 'BDK', 'BDL', 'BDN', 'BDX', 'BDY', 'BE', 'BEAM', 'BEC', 'BED', 'BEL', 'BEM', 'BEN', 'BEST', 'BETA', 'BEV', 'BEZ', 'BF', 'BFAM', 'BFC', 'BFCI', 'BFD', 'BFO', 'BFR', 'BFS', 'BFT', 'BGA', 'BGC', 'BGG', 'BGL', 'BGO', 'BGP', 'BGR', 'BGT', 'BGY', 'BH', 'BHC', 'BHE', 'BHI', 'BHP', 'BHW', 'BHY', 'BI', 'BID', 'BILL', 'BIN', 'BIO', 'BIOM', 'BIR', 'BJ', 'BJS', 'BK', 'BKC', 'BKE', 'BKF', 'BKH', 'BKI', 'BKLY', 'BKN', 'BKR', 'BKS', 'BKT', 'BLC', 'BLD', 'BLE', 'BLK', 'BLL', 'BLN', 'BLS', 'BLT', 'BLU', 'BLX', 'BMC', 'BMCS', 'BMG', 'BMHC', 'BMI', 'BMN', 'BMO', 'BMS', 'BMT', 'BMY', 'BN', 'BNA', 'BNE', 'BNG', 'BNI', 'BNL', 'BNO', 'BNS', 'BNT', 'BOA', 'BOG', 'BOH', 'BOL', 'BOOT', 'BOP', 'BOR', 'BOS', 'BOW', 'BOX', 'BOY', 'BPA', 'BPC', 'BPL', 'BPO', 'BPP', 'BPRX', 'BPT', 'BQT', 'BR', 'BRC', 'BRE', 'BRF', 'BRK', 'BRL', 'BRM', 'BRO', 'BRR', 'BRS', 'BRT', 'BRW', 'BRY', 'BS', 'BSB', 'BSC', 'BSD', 'BSH', 'BSI', 'BSP', 'BSTI', 'BSX', 'BSY', 'BSYS', 'BTF', 'BTH', 'BTI', 'BTM', 'BTN', 'BTO', 'BTR', 'BTT', 'BTY', 'BTZ', 'BUD', 'BUR', 'BVC', 'BVF', 'BVN', 'BW', 'BWA', 'BWC', 'BWE', 'BWG', 'BWP', 'BWS', 'BXG', 'BXL', 'BXM', 'BXP', 'BXS', 'BXT', 'BY', 'BYD', 'BYH', 'BZ', 'BZF', 'BZH', 'BZL', 'C', 'CA', 'CAA', 'CAB', 'CACI', 'CACOA', 'CADE', 'CAE', 'CAF', 'CAG', 'CAH', 'CAL', 'CAM', 'CAN', 'CANNY', 'CAO', 'CAP', 'CAR', 'CARL', 'CARN', 'CARS', 'CAS', 'CASC', 'CAT', 'CAV', 'CB', 'CBA', 'CBC', 'CBCL', 'CBE', 'CBG', 'CBH', 'CBI', 'CBIZ', 'CBK', 'CBL', 'CBLI', 'CBM', 'CBR', 'CBS', 'CBT', 'CBU', 'CBZ', 'CC', 'CCB', 'CCC', 'CCE', 'CCG', 'CCH', 'CCJ', 'CCK', 'CCL', 'CCN', 'CCOM', 'CCR', 'CCS', 'CCU', 'CD', 'CDA', 'CDB', 'CDC', 'CDCY', 'CDD', 'CDE', 'CDF', 'CDI', 'CDIS', 'CDL', 'CDN', 'CDO', 'CDP', 'CDT', 'CDX', 'CEA', 'CEC', 'CEE', 'CEFT', 'CEG', 'CEI', 'CEL', 'CEM', 'CEN', 'CF', 'CFA', 'CFB', 'CFCM', 'CFD', 'CFI', 'CFK', 'CFR', 'CFS', 'CFX', 'CG', 'CGA', 'CGC ...
# Processed clustering for window ending 2000-02-03
# {'date': Timestamp('2000-02-03 00:00:00'), 'tickers': ['AA', 'AAC', 'AAG', 'AAIR', 'AAM', 'AAP', 'AAS', 'AAT', 'AB', 'ABERF', 'ABF', 'ABG', 'ABK', 'ABM', 'ABMD', 'ABN', 'ABP', 'ABR', 'ABRI', 'ABS', 'ABT', 'ABX', 'ABY', 'AC', 'ACEE', 'ACF', 'ACG', 'ACI', 'ACK', 'ACL', 'ACLNF', 'ACN', 'ACO', 'ACP', 'ACR', 'ACRG', 'ACS', 'ACTN', 'ACV', 'ACX', 'ACXM', 'AD', 'ADC', 'ADECY', 'ADF', 'ADG', 'ADI', 'ADM', 'ADMS', 'ADP', 'ADPT', 'ADV', 'ADX', 'AEC', 'AED', 'AEE', 'AEG', 'AEM', 'AEOS', 'AEP', 'AER', 'AES', 'AET', 'AF', 'AFC', 'AFF', 'AFG', 'AFL', 'AFM', 'AFP', 'AFS', 'AG', 'AGA', 'AGC', 'AGE', 'AGI', 'AGL', 'AGM', 'AGN', 'AGR', 'AGS', 'AGTX', 'AGU', 'AGX', 'AGY', 'AH', 'AHC', 'AHG', 'AHI', 'AHMH', 'AHO', 'AHP', 'AHR', 'AIB', 'AIC', 'AIF', 'AIG', 'AIN', 'AIR', 'AIV', 'AIZ', 'AJG', 'AJL', 'AJX', 'AK', 'AKO', 'AKR', 'AKS', 'AL', 'ALA', 'ALB', 'ALC', 'ALEX', 'ALG', 'ALK', 'ALL', 'ALLC', 'ALLE', 'ALLY', 'ALM', 'ALN', 'ALO', 'ALR', 'ALRE', 'ALS', 'ALU', 'ALV', 'ALX', 'AM', 'AMB', 'AMC', 'AMCR', 'AMD', 'AME', 'AMF', 'AMG', 'AMH', 'AMI', 'AMK', 'AML', 'AMN', 'AMO', 'AMR', 'AMSGA', 'AMT', 'AMTD', 'AMU', 'AMZ', 'AN', 'ANET', 'ANF', 'ANFI', 'ANH', 'ANN', 'ANS', 'ANZ', 'AOC', 'AOF', 'AOG', 'AOI', 'AOL', 'AOR', 'AOS', 'AP', 'APA', 'APB', 'APC', 'APD', 'APF', 'APGR', 'APH', 'APL', 'APM', 'APO', 'APR', 'APS', 'APU', 'APW', 'APX', 'APZ', 'AQM', 'ARA', 'ARB', 'ARC', 'ARE', 'ARG', 'ARGX', 'ARH', 'ARI', 'ARJ', 'ARK', 'ARMF', 'ARSD', 'ART', 'ARV', 'ARW', 'ARX', 'ASA', 'ASBC', 'ASD', 'ASF', 'ASFC', 'ASG', 'ASGN', 'ASH', 'ASI', 'ASL', 'ASN', 'ASO', 'ASP', 'ASV', 'AT', 'ATC', 'ATEC', 'ATG', 'ATHM', 'ATI', 'ATK', 'ATL', 'ATO', 'ATR', 'ATS', 'ATV', 'ATW', 'ATY', 'AU', 'AUD', 'AVA', 'AVB', 'AVD', 'AVE', 'AVI', 'AVL', 'AVP', 'AVS', 'AVT', 'AVTR', 'AVX', 'AVY', 'AVZ', 'AW', 'AWA', 'AWC', 'AWF', 'AWG', 'AWK', 'AWR', 'AXA', 'AXE', 'AXF', 'AXL', 'AXM', 'AXP', 'AXR', 'AXT', 'AYE', 'AZA', 'AZN', 'AZO', 'AZR', 'AZUR', 'AZX', 'AZZ', 'B', 'BA', 'BAB', 'BAC', 'BALT', 'BANC', 'BAP', 'BAS', 'BAT', 'BAU', 'BAX', 'BB', 'BBA', 'BBAR', 'BBC', 'BBDC', 'BBI', 'BBR', 'BBT', 'BBV', 'BBX', 'BBY', 'BC', 'BCC', 'BCE', 'BCF', 'BCM', 'BCR', 'BCS', 'BCU', 'BD', 'BDE', 'BDF', 'BDG', 'BDK', 'BDL', 'BDN', 'BDX', 'BDY', 'BE', 'BEAM', 'BEC', 'BED', 'BEL', 'BEM', 'BEN', 'BEST', 'BETA', 'BEV', 'BEZ', 'BF', 'BFAM', 'BFC', 'BFCI', 'BFD', 'BFO', 'BFR', 'BFS', 'BFT', 'BGA', 'BGC', 'BGG', 'BGL', 'BGO', 'BGP', 'BGR', 'BGT', 'BGY', 'BH', 'BHC', 'BHE', 'BHI', 'BHP', 'BHW', 'BHY', 'BI', 'BID', 'BILL', 'BIN', 'BIO', 'BIOM', 'BIR', 'BJ', 'BJS', 'BK', 'BKC', 'BKE', 'BKF', 'BKH', 'BKI', 'BKLY', 'BKN', 'BKR', 'BKS', 'BKT', 'BLC', 'BLD', 'BLE', 'BLK', 'BLL', 'BLN', 'BLS', 'BLT', 'BLU', 'BLX', 'BMC', 'BMCS', 'BMG', 'BMHC', 'BMI', 'BMN', 'BMO', 'BMS', 'BMT', 'BMY', 'BN', 'BNA', 'BNE', 'BNG', 'BNI', 'BNL', 'BNO', 'BNS', 'BNT', 'BOA', 'BOG', 'BOH', 'BOL', 'BOOT', 'BOP', 'BOR', 'BOS', 'BOW', 'BOX', 'BOY', 'BPA', 'BPC', 'BPL', 'BPO', 'BPP', 'BPRX', 'BPT', 'BQT', 'BR', 'BRC', 'BRE', 'BRF', 'BRK', 'BRL', 'BRM', 'BRO', 'BRR', 'BRS', 'BRT', 'BRW', 'BRY', 'BS', 'BSB', 'BSC', 'BSD', 'BSH', 'BSI', 'BSP', 'BSTI', 'BSX', 'BSY', 'BSYS', 'BTF', 'BTH', 'BTI', 'BTM', 'BTN', 'BTO', 'BTR', 'BTT', 'BTY', 'BTZ', 'BUD', 'BUR', 'BVC', 'BVF', 'BVN', 'BW', 'BWA', 'BWC', 'BWE', 'BWG', 'BWP', 'BWS', 'BXG', 'BXL', 'BXM', 'BXP', 'BXS', 'BXT', 'BY', 'BYD', 'BYH', 'BZ', 'BZF', 'BZH', 'BZL', 'C', 'CA', 'CAA', 'CAB', 'CACI', 'CACOA', 'CADE', 'CAE', 'CAF', 'CAG', 'CAH', 'CAL', 'CAM', 'CAN', 'CANNY', 'CAO', 'CAP', 'CAR', 'CARL', 'CARN', 'CARS', 'CAS', 'CASC', 'CAT', 'CAV', 'CB', 'CBA', 'CBC', 'CBCL', 'CBE', 'CBG', 'CBH', 'CBI', 'CBIZ', 'CBK', 'CBL', 'CBLI', 'CBM', 'CBR', 'CBS', 'CBT', 'CBU', 'CBZ', 'CC', 'CCB', 'CCC', 'CCE', 'CCG', 'CCH', 'CCJ', 'CCK', 'CCL', 'CCN', 'CCOM', 'CCR', 'CCS', 'CCU', 'CD', 'CDA', 'CDB', 'CDC', 'CDCY', 'CDD', 'CDE', 'CDF', 'CDI', 'CDIS', 'CDL', 'CDN', 'CDO', 'CDP', 'CDT', 'CDX', 'CEA', 'CEC', 'CEE', 'CEFT', 'CEG', 'CEI', 'CEL', 'CEM', 'CEN', 'CF', 'CFA', 'CFB', 'CFCM', 'CFD', 'CFI', 'CFK', 'CFR', 'CFS', 'CFX', 'CG', 'CGA ...
# Processed clustering for window ending 2000-02-04
# {'date': Timestamp('2000-02-04 00:00:00'), 'tickers': ['AA', 'AAC', 'AAG', 'AAIR', 'AAM', 'AAP', 'AAS', 'AAT', 'AB', 'ABERF', 'ABF', 'ABG', 'ABK', 'ABM', 'ABMD', 'ABN', 'ABP', 'ABR', 'ABRI', 'ABS', 'ABT', 'ABX', 'ABY', 'AC', 'ACEE', 'ACF', 'ACG', 'ACI', 'ACK', 'ACL', 'ACLNF', 'ACN', 'ACO', 'ACP', 'ACR', 'ACRG', 'ACS', 'ACTN', 'ACV', 'ACX', 'ACXM', 'AD', 'ADC', 'ADECY', 'ADF', 'ADG', 'ADI', 'ADM', 'ADMS', 'ADP', 'ADPT', 'ADV', 'ADX', 'AEC', 'AED', 'AEE', 'AEG', 'AEM', 'AEOS', 'AEP', 'AER', 'AES', 'AET', 'AF', 'AFC', 'AFF', 'AFG', 'AFL', 'AFM', 'AFP', 'AFS', 'AG', 'AGA', 'AGC', 'AGE', 'AGI', 'AGL', 'AGM', 'AGN', 'AGR', 'AGS', 'AGTX', 'AGU', 'AGX', 'AGY', 'AH', 'AHC', 'AHG', 'AHI', 'AHMH', 'AHO', 'AHP', 'AHR', 'AIB', 'AIC', 'AIF', 'AIG', 'AIN', 'AIR', 'AIV', 'AIZ', 'AJG', 'AJL', 'AJX', 'AK', 'AKO', 'AKR', 'AKS', 'AL', 'ALA', 'ALB', 'ALC', 'ALEX', 'ALG', 'ALK', 'ALL', 'ALLC', 'ALLE', 'ALLY', 'ALM', 'ALN', 'ALO', 'ALR', 'ALRE', 'ALS', 'ALU', 'ALV', 'ALX', 'AM', 'AMB', 'AMC', 'AMCR', 'AMD', 'AME', 'AMF', 'AMG', 'AMH', 'AMI', 'AMK', 'AML', 'AMN', 'AMO', 'AMR', 'AMSGA', 'AMT', 'AMTD', 'AMU', 'AMZ', 'AN', 'ANET', 'ANF', 'ANFI', 'ANH', 'ANN', 'ANS', 'ANZ', 'AOC', 'AOF', 'AOG', 'AOI', 'AOL', 'AOR', 'AOS', 'AP', 'APA', 'APB', 'APC', 'APD', 'APF', 'APGR', 'APH', 'APL', 'APM', 'APO', 'APR', 'APS', 'APU', 'APW', 'APX', 'APZ', 'AQM', 'ARA', 'ARB', 'ARC', 'ARE', 'ARG', 'ARGX', 'ARH', 'ARI', 'ARJ', 'ARK', 'ARMF', 'ARSD', 'ART', 'ARV', 'ARW', 'ARX', 'ASA', 'ASBC', 'ASD', 'ASF', 'ASFC', 'ASG', 'ASGN', 'ASH', 'ASI', 'ASL', 'ASN', 'ASO', 'ASP', 'ASV', 'AT', 'ATC', 'ATEC', 'ATG', 'ATHM', 'ATI', 'ATK', 'ATL', 'ATO', 'ATR', 'ATS', 'ATV', 'ATW', 'ATY', 'AU', 'AUD', 'AVA', 'AVB', 'AVD', 'AVE', 'AVI', 'AVL', 'AVP', 'AVS', 'AVT', 'AVTR', 'AVX', 'AVY', 'AVZ', 'AW', 'AWA', 'AWC', 'AWF', 'AWG', 'AWK', 'AWR', 'AXA', 'AXE', 'AXF', 'AXL', 'AXM', 'AXP', 'AXR', 'AXT', 'AYE', 'AZA', 'AZN', 'AZO', 'AZR', 'AZUR', 'AZX', 'AZZ', 'B', 'BA', 'BAB', 'BAC', 'BALT', 'BANC', 'BAP', 'BAS', 'BAT', 'BAU', 'BAX', 'BB', 'BBA', 'BBAR', 'BBC', 'BBDC', 'BBI', 'BBR', 'BBT', 'BBV', 'BBX', 'BBY', 'BC', 'BCC', 'BCE', 'BCF', 'BCM', 'BCR', 'BCS', 'BCU', 'BD', 'BDE', 'BDF', 'BDG', 'BDK', 'BDL', 'BDN', 'BDX', 'BDY', 'BE', 'BEAM', 'BEC', 'BED', 'BEL', 'BEM', 'BEN', 'BEST', 'BETA', 'BEV', 'BEZ', 'BF', 'BFAM', 'BFC', 'BFCI', 'BFD', 'BFO', 'BFR', 'BFS', 'BFT', 'BGA', 'BGC', 'BGG', 'BGL', 'BGO', 'BGP', 'BGR', 'BGT', 'BGY', 'BH', 'BHC', 'BHE', 'BHI', 'BHP', 'BHW', 'BHY', 'BI', 'BID', 'BILL', 'BIN', 'BIO', 'BIOM', 'BIR', 'BJ', 'BJS', 'BK', 'BKC', 'BKE', 'BKF', 'BKH', 'BKI', 'BKLY', 'BKN', 'BKR', 'BKS', 'BKT', 'BLC', 'BLD', 'BLE', 'BLK', 'BLL', 'BLN', 'BLS', 'BLT', 'BLU', 'BLX', 'BMC', 'BMCS', 'BMG', 'BMHC', 'BMI', 'BMN', 'BMO', 'BMS', 'BMT', 'BMY', 'BN', 'BNA', 'BNE', 'BNG', 'BNI', 'BNL', 'BNO', 'BNS', 'BNT', 'BOA', 'BOG', 'BOH', 'BOL', 'BOOT', 'BOP', 'BOR', 'BOS', 'BOW', 'BOX', 'BOY', 'BPA', 'BPC', 'BPL', 'BPO', 'BPP', 'BPRX', 'BPT', 'BQT', 'BR', 'BRC', 'BRE', 'BRF', 'BRK', 'BRL', 'BRM', 'BRO', 'BRR', 'BRS', 'BRT', 'BRW', 'BRY', 'BS', 'BSB', 'BSC', 'BSD', 'BSH', 'BSI', 'BSP', 'BSTI', 'BSX', 'BSY', 'BSYS', 'BTF', 'BTH', 'BTI', 'BTM', 'BTN', 'BTO', 'BTR', 'BTT', 'BTY', 'BTZ', 'BUD', 'BUR', 'BVC', 'BVF', 'BVN', 'BW', 'BWA', 'BWC', 'BWE', 'BWG', 'BWP', 'BWS', 'BXG', 'BXL', 'BXM', 'BXP', 'BXS', 'BXT', 'BY', 'BYD', 'BYH', 'BZ', 'BZF', 'BZH', 'BZL', 'C', 'CA', 'CAA', 'CAB', 'CACI', 'CACOA', 'CADE', 'CAE', 'CAF', 'CAG', 'CAH', 'CAL', 'CAM', 'CAN', 'CANNY', 'CAO', 'CAP', 'CAR', 'CARL', 'CARN', 'CARS', 'CAS', 'CASC', 'CAT', 'CAV', 'CB', 'CBA', 'CBC', 'CBCL', 'CBE', 'CBG', 'CBH', 'CBI', 'CBIZ', 'CBK', 'CBL', 'CBLI', 'CBM', 'CBR', 'CBS', 'CBT', 'CBU', 'CBZ', 'CC', 'CCB', 'CCC', 'CCE', 'CCG', 'CCH', 'CCJ', 'CCK', 'CCL', 'CCN', 'CCOM', 'CCR', 'CCS', 'CCU', 'CD', 'CDA', 'CDB', 'CDC', 'CDCY', 'CDD', 'CDE', 'CDF', 'CDI', 'CDIS', 'CDL', 'CDN', 'CDO', 'CDP', 'CDT', 'CDX', 'CEA', 'CEC', 'CEE', 'CEFT', 'CEG', 'CEI', 'CEL', 'CEM', 'CEN', 'CF', 'CFA', 'CFB', 'CFCM', 'CFD', 'CFI', 'CFK', 'CFR', 'CFS', 'CFX', 'CG', 'CGA ...
# Processed clustering for window ending 2000-02-07
# {'date': Timestamp('2000-02-07 00:00:00'), 'tickers': ['AA', 'AAC', 'AAG', 'AAIR', 'AAM', 'AAP', 'AAS', 'AAT', 'AB', 'ABERF', 'ABF', 'ABG', 'ABK', 'ABM', 'ABMD', 'ABN', 'ABP', 'ABR', 'ABRI', 'ABS', 'ABT', 'ABX', 'ABY', 'AC', 'ACEE', 'ACF', 'ACG', 'ACI', 'ACK', 'ACL', 'ACLNF', 'ACN', 'ACO', 'ACP', 'ACR', 'ACRG', 'ACS', 'ACTN', 'ACV', 'ACX', 'ACXM', 'AD', 'ADC', 'ADECY', 'ADF', 'ADG', 'ADI', 'ADM', 'ADMS', 'ADP', 'ADPT', 'ADV', 'ADX', 'AEC', 'AED', 'AEE', 'AEG', 'AEM', 'AEOS', 'AEP', 'AER', 'AES', 'AET', 'AF', 'AFC', 'AFF', 'AFG', 'AFL', 'AFM', 'AFP', 'AFS', 'AG', 'AGA', 'AGC', 'AGE', 'AGI', 'AGL', 'AGM', 'AGN', 'AGR', 'AGS', 'AGTX', 'AGU', 'AGX', 'AGY', 'AH', 'AHC', 'AHG', 'AHI', 'AHMH', 'AHO', 'AHP', 'AHR', 'AIB', 'AIC', 'AIF', 'AIG', 'AIN', 'AIR', 'AIV', 'AIZ', 'AJG', 'AJL', 'AJX', 'AK', 'AKO', 'AKR', 'AKS', 'AL', 'ALA', 'ALB', 'ALC', 'ALEX', 'ALG', 'ALK', 'ALL', 'ALLC', 'ALLE', 'ALLY', 'ALM', 'ALN', 'ALO', 'ALR', 'ALRE', 'ALS', 'ALU', 'ALV', 'ALX', 'AM', 'AMB', 'AMC', 'AMCR', 'AMD', 'AME', 'AMF', 'AMG', 'AMH', 'AMI', 'AMK', 'AML', 'AMN', 'AMO', 'AMR', 'AMSGA', 'AMT', 'AMTD', 'AMU', 'AMZ', 'AN', 'ANET', 'ANF', 'ANFI', 'ANH', 'ANN', 'ANS', 'ANZ', 'AOC', 'AOF', 'AOG', 'AOI', 'AOL', 'AOR', 'AOS', 'AP', 'APA', 'APB', 'APC', 'APD', 'APF', 'APGR', 'APH', 'APL', 'APO', 'APR', 'APS', 'APU', 'APW', 'APX', 'APZ', 'AQM', 'ARA', 'ARB', 'ARC', 'ARE', 'ARG', 'ARGX', 'ARH', 'ARI', 'ARJ', 'ARK', 'ARMF', 'ARSD', 'ART', 'ARV', 'ARW', 'ARX', 'ASA', 'ASBC', 'ASD', 'ASF', 'ASFC', 'ASG', 'ASGN', 'ASH', 'ASI', 'ASL', 'ASN', 'ASO', 'ASP', 'ASV', 'AT', 'ATC', 'ATEC', 'ATG', 'ATHM', 'ATI', 'ATK', 'ATL', 'ATO', 'ATR', 'ATS', 'ATV', 'ATW', 'ATY', 'AU', 'AUD', 'AVA', 'AVB', 'AVD', 'AVE', 'AVI', 'AVL', 'AVP', 'AVS', 'AVT', 'AVTR', 'AVX', 'AVY', 'AVZ', 'AW', 'AWA', 'AWC', 'AWF', 'AWG', 'AWK', 'AWR', 'AXA', 'AXE', 'AXF', 'AXL', 'AXM', 'AXP', 'AXR', 'AXT', 'AYE', 'AZA', 'AZN', 'AZO', 'AZR', 'AZUR', 'AZX', 'AZZ', 'B', 'BA', 'BAB', 'BAC', 'BALT', 'BANC', 'BAP', 'BAS', 'BAT', 'BAU', 'BAX', 'BB', 'BBA', 'BBAR', 'BBC', 'BBDC', 'BBI', 'BBR', 'BBT', 'BBV', 'BBX', 'BBY', 'BC', 'BCC', 'BCE', 'BCF', 'BCM', 'BCR', 'BCS', 'BCU', 'BD', 'BDE', 'BDF', 'BDG', 'BDK', 'BDL', 'BDN', 'BDX', 'BDY', 'BE', 'BEAM', 'BEC', 'BED', 'BEL', 'BEM', 'BEN', 'BEST', 'BETA', 'BEV', 'BEZ', 'BF', 'BFAM', 'BFC', 'BFCI', 'BFD', 'BFO', 'BFR', 'BFS', 'BFT', 'BGA', 'BGC', 'BGG', 'BGL', 'BGO', 'BGP', 'BGR', 'BGT', 'BGY', 'BH', 'BHC', 'BHE', 'BHI', 'BHP', 'BHW', 'BHY', 'BI', 'BID', 'BILL', 'BIN', 'BIO', 'BIOM', 'BIR', 'BJ', 'BJS', 'BK', 'BKC', 'BKE', 'BKF', 'BKH', 'BKI', 'BKLY', 'BKN', 'BKR', 'BKS', 'BKT', 'BLC', 'BLD', 'BLE', 'BLK', 'BLL', 'BLN', 'BLS', 'BLT', 'BLU', 'BLX', 'BMC', 'BMCS', 'BMG', 'BMHC', 'BMI', 'BMN', 'BMO', 'BMS', 'BMT', 'BMY', 'BN', 'BNA', 'BNE', 'BNG', 'BNI', 'BNO', 'BNS', 'BNT', 'BOA', 'BOG', 'BOH', 'BOL', 'BOOT', 'BOP', 'BOR', 'BOS', 'BOW', 'BOX', 'BOY', 'BPA', 'BPC', 'BPL', 'BPO', 'BPP', 'BPRX', 'BPT', 'BQT', 'BR', 'BRC', 'BRE', 'BRF', 'BRK', 'BRL', 'BRM', 'BRO', 'BRR', 'BRS', 'BRT', 'BRW', 'BRY', 'BS', 'BSB', 'BSC', 'BSD', 'BSH', 'BSI', 'BSP', 'BSTI', 'BSX', 'BSY', 'BSYS', 'BTF', 'BTH', 'BTI', 'BTM', 'BTN', 'BTO', 'BTR', 'BTT', 'BTY', 'BTZ', 'BUD', 'BUR', 'BVC', 'BVF', 'BVN', 'BW', 'BWA', 'BWC', 'BWE', 'BWG', 'BWP', 'BWS', 'BXG', 'BXL', 'BXM', 'BXP', 'BXS', 'BXT', 'BY', 'BYD', 'BYH', 'BZ', 'BZF', 'BZH', 'BZL', 'C', 'CA', 'CAA', 'CAB', 'CACI', 'CACOA', 'CADE', 'CAE', 'CAF', 'CAG', 'CAH', 'CAL', 'CAM', 'CAN', 'CANNY', 'CAO', 'CAP', 'CAR', 'CARL', 'CARN', 'CARS', 'CAS', 'CASC', 'CAT', 'CAV', 'CB', 'CBA', 'CBC', 'CBCL', 'CBE', 'CBG', 'CBH', 'CBI', 'CBIZ', 'CBK', 'CBL', 'CBLI', 'CBM', 'CBR', 'CBS', 'CBT', 'CBU', 'CBZ', 'CC', 'CCB', 'CCC', 'CCE', 'CCG', 'CCH', 'CCJ', 'CCK', 'CCL', 'CCN', 'CCOM', 'CCR', 'CCS', 'CCU', 'CD', 'CDA', 'CDB', 'CDC', 'CDCY', 'CDD', 'CDE', 'CDF', 'CDI', 'CDIS', 'CDL', 'CDN', 'CDO', 'CDP', 'CDT', 'CDX', 'CEA', 'CEC', 'CEE', 'CEFT', 'CEG', 'CEI', 'CEL', 'CEM', 'CEN', 'CF', 'CFA', 'CFB', 'CFCM', 'CFD', 'CFI', 'CFK', 'CFR', 'CFS', 'CFX', 'CG', 'CGA', 'CGC', 'CGF ...
# Processed clustering for window ending 2000-02-08
# {'date': Timestamp('2000-02-08 00:00:00'), 'tickers': ['AA', 'AAC', 'AAG', 'AAIR', 'AAM', 'AAP', 'AAS', 'AAT', 'AB', 'ABERF', 'ABF', 'ABG', 'ABK', 'ABM', 'ABMD', 'ABN', 'ABP', 'ABR', 'ABRI', 'ABS', 'ABT', 'ABX', 'ABY', 'AC', 'ACEE', 'ACF', 'ACG', 'ACI', 'ACK', 'ACL', 'ACLNF', 'ACN', 'ACO', 'ACP', 'ACR', 'ACRG', 'ACS', 'ACTN', 'ACV', 'ACX', 'ACXM', 'AD', 'ADC', 'ADECY', 'ADF', 'ADG', 'ADI', 'ADM', 'ADMS', 'ADP', 'ADPT', 'ADV', 'ADX', 'AEC', 'AED', 'AEE', 'AEG', 'AEM', 'AEOS', 'AEP', 'AER', 'AES', 'AET', 'AF', 'AFC', 'AFF', 'AFG', 'AFL', 'AFM', 'AFP', 'AFS', 'AG', 'AGA', 'AGC', 'AGE', 'AGI', 'AGL', 'AGM', 'AGN', 'AGR', 'AGS', 'AGTX', 'AGU', 'AGX', 'AGY', 'AH', 'AHC', 'AHG', 'AHI', 'AHMH', 'AHO', 'AHP', 'AHR', 'AIB', 'AIC', 'AIF', 'AIG', 'AIN', 'AIR', 'AIV', 'AIZ', 'AJG', 'AJL', 'AJX', 'AK', 'AKO', 'AKR', 'AKS', 'AL', 'ALA', 'ALB', 'ALC', 'ALEX', 'ALG', 'ALK', 'ALL', 'ALLC', 'ALLE', 'ALLY', 'ALM', 'ALN', 'ALO', 'ALR', 'ALRE', 'ALS', 'ALU', 'ALV', 'ALX', 'AM', 'AMB', 'AMC', 'AMCR', 'AMD', 'AME', 'AMF', 'AMG', 'AMH', 'AMI', 'AMK', 'AML', 'AMN', 'AMO', 'AMR', 'AMSGA', 'AMT', 'AMTD', 'AMU', 'AMZ', 'AN', 'ANET', 'ANF', 'ANFI', 'ANH', 'ANN', 'ANS', 'ANZ', 'AOC', 'AOF', 'AOG', 'AOI', 'AOL', 'AOR', 'AOS', 'AP', 'APA', 'APB', 'APC', 'APCS', 'APD', 'APF', 'APGR', 'APH', 'APL', 'APO', 'APR', 'APS', 'APU', 'APW', 'APX', 'APZ', 'AQM', 'ARA', 'ARB', 'ARC', 'ARE', 'ARG', 'ARGX', 'ARH', 'ARI', 'ARJ', 'ARK', 'ARMF', 'ARSD', 'ART', 'ARV', 'ARW', 'ARX', 'ASA', 'ASBC', 'ASD', 'ASF', 'ASFC', 'ASG', 'ASGN', 'ASH', 'ASI', 'ASL', 'ASN', 'ASO', 'ASP', 'ASV', 'AT', 'ATC', 'ATEC', 'ATG', 'ATHM', 'ATI', 'ATK', 'ATL', 'ATO', 'ATR', 'ATS', 'ATV', 'ATW', 'ATY', 'AU', 'AUD', 'AVA', 'AVB', 'AVD', 'AVE', 'AVI', 'AVL', 'AVP', 'AVS', 'AVT', 'AVTR', 'AVX', 'AVY', 'AVZ', 'AW', 'AWA', 'AWC', 'AWF', 'AWG', 'AWK', 'AWR', 'AXA', 'AXE', 'AXF', 'AXL', 'AXM', 'AXP', 'AXR', 'AXT', 'AYE', 'AZA', 'AZN', 'AZO', 'AZR', 'AZUR', 'AZX', 'AZZ', 'B', 'BA', 'BAB', 'BAC', 'BALT', 'BANC', 'BAP', 'BAS', 'BAT', 'BAU', 'BAX', 'BB', 'BBA', 'BBAR', 'BBC', 'BBDC', 'BBI', 'BBR', 'BBT', 'BBV', 'BBX', 'BBY', 'BC', 'BCC', 'BCE', 'BCF', 'BCM', 'BCR', 'BCS', 'BCU', 'BD', 'BDE', 'BDF', 'BDG', 'BDK', 'BDL', 'BDN', 'BDX', 'BDY', 'BE', 'BEAM', 'BEC', 'BED', 'BEL', 'BEM', 'BEN', 'BEST', 'BETA', 'BEV', 'BEZ', 'BF', 'BFAM', 'BFC', 'BFCI', 'BFD', 'BFO', 'BFR', 'BFS', 'BFT', 'BGA', 'BGC', 'BGG', 'BGL', 'BGO', 'BGP', 'BGR', 'BGT', 'BGY', 'BH', 'BHC', 'BHE', 'BHI', 'BHP', 'BHW', 'BHY', 'BI', 'BID', 'BILL', 'BIN', 'BIO', 'BIOM', 'BIR', 'BJ', 'BJS', 'BK', 'BKC', 'BKE', 'BKF', 'BKH', 'BKI', 'BKLY', 'BKN', 'BKR', 'BKS', 'BKT', 'BLC', 'BLD', 'BLE', 'BLK', 'BLL', 'BLN', 'BLS', 'BLT', 'BLU', 'BLX', 'BMC', 'BMCS', 'BMG', 'BMHC', 'BMI', 'BMN', 'BMO', 'BMS', 'BMT', 'BMY', 'BN', 'BNA', 'BNE', 'BNG', 'BNI', 'BNO', 'BNS', 'BNT', 'BOA', 'BOG', 'BOH', 'BOL', 'BOOT', 'BOP', 'BOR', 'BOS', 'BOW', 'BOX', 'BOY', 'BPA', 'BPC', 'BPL', 'BPO', 'BPP', 'BPRX', 'BPT', 'BQT', 'BR', 'BRC', 'BRE', 'BRF', 'BRK', 'BRL', 'BRM', 'BRO', 'BRR', 'BRS', 'BRT', 'BRW', 'BRY', 'BS', 'BSB', 'BSC', 'BSD', 'BSH', 'BSI', 'BSP', 'BSTI', 'BSX', 'BSY', 'BSYS', 'BTF', 'BTH', 'BTI', 'BTM', 'BTN', 'BTO', 'BTR', 'BTT', 'BTY', 'BTZ', 'BUD', 'BUR', 'BVC', 'BVF', 'BVN', 'BW', 'BWA', 'BWC', 'BWE', 'BWG', 'BWP', 'BWS', 'BXG', 'BXL', 'BXM', 'BXP', 'BXS', 'BXT', 'BY', 'BYD', 'BYH', 'BZ', 'BZF', 'BZH', 'BZL', 'C', 'CA', 'CAA', 'CAB', 'CACI', 'CACOA', 'CADE', 'CAE', 'CAF', 'CAG', 'CAH', 'CAL', 'CAM', 'CAN', 'CANNY', 'CAO', 'CAP', 'CAR', 'CARL', 'CARN', 'CARS', 'CAS', 'CASC', 'CAT', 'CAV', 'CB', 'CBA', 'CBC', 'CBCL', 'CBE', 'CBG', 'CBH', 'CBI', 'CBIZ', 'CBK', 'CBL', 'CBLI', 'CBM', 'CBR', 'CBS', 'CBT', 'CBU', 'CBZ', 'CC', 'CCB', 'CCC', 'CCE', 'CCG', 'CCH', 'CCJ', 'CCK', 'CCL', 'CCN', 'CCOM', 'CCR', 'CCS', 'CCU', 'CD', 'CDA', 'CDB', 'CDC', 'CDCY', 'CDD', 'CDE', 'CDF', 'CDI', 'CDIS', 'CDL', 'CDN', 'CDO', 'CDP', 'CDT', 'CDX', 'CEA', 'CEC', 'CEE', 'CEFT', 'CEG', 'CEI', 'CEL', 'CEM', 'CEN', 'CF', 'CFA', 'CFB', 'CFCM', 'CFD', 'CFI', 'CFK', 'CFR', 'CFS', 'CFX', 'CG', 'CGA', 'CG ...
# Processed clustering for window ending 2000-02-09
# {'date': Timestamp('2000-02-09 00:00:00'), 'tickers': ['AA', 'AAC', 'AAG', 'AAIR', 'AAM', 'AAP', 'AAS', 'AAT', 'AB', 'ABERF', 'ABF', 'ABG', 'ABK', 'ABM', 'ABMD', 'ABN', 'ABP', 'ABR', 'ABRI', 'ABS', 'ABT', 'ABX', 'ABY', 'AC', 'ACEE', 'ACF', 'ACG', 'ACI', 'ACK', 'ACL', 'ACLNF', 'ACN', 'ACO', 'ACP', 'ACR', 'ACRG', 'ACS', 'ACTN', 'ACV', 'ACX', 'ACXM', 'AD', 'ADC', 'ADECY', 'ADF', 'ADG', 'ADI', 'ADM', 'ADMS', 'ADP', 'ADPT', 'ADV', 'ADX', 'AEC', 'AED', 'AEE', 'AEG', 'AEM', 'AEOS', 'AEP', 'AER', 'AES', 'AET', 'AF', 'AFC', 'AFF', 'AFG', 'AFL', 'AFM', 'AFP', 'AFS', 'AG', 'AGA', 'AGC', 'AGE', 'AGI', 'AGL', 'AGM', 'AGN', 'AGR', 'AGS', 'AGTX', 'AGU', 'AGX', 'AGY', 'AH', 'AHC', 'AHG', 'AHI', 'AHMH', 'AHO', 'AHP', 'AHR', 'AIB', 'AIC', 'AIF', 'AIG', 'AIN', 'AIR', 'AIV', 'AIZ', 'AJG', 'AJL', 'AJX', 'AK', 'AKO', 'AKR', 'AKS', 'AL', 'ALA', 'ALB', 'ALC', 'ALEX', 'ALG', 'ALK', 'ALL', 'ALLC', 'ALLE', 'ALLY', 'ALM', 'ALN', 'ALO', 'ALR', 'ALRE', 'ALS', 'ALU', 'ALV', 'ALX', 'AM', 'AMB', 'AMC', 'AMCR', 'AMD', 'AME', 'AMF', 'AMG', 'AMH', 'AMI', 'AMK', 'AML', 'AMN', 'AMO', 'AMR', 'AMSGA', 'AMT', 'AMTD', 'AMU', 'AMZ', 'AN', 'ANET', 'ANF', 'ANFI', 'ANH', 'ANN', 'ANS', 'ANZ', 'AOC', 'AOF', 'AOG', 'AOI', 'AOL', 'AOR', 'AOS', 'AP', 'APA', 'APB', 'APC', 'APCS', 'APD', 'APF', 'APGR', 'APH', 'APL', 'APO', 'APR', 'APS', 'APU', 'APW', 'APX', 'APZ', 'AQM', 'ARA', 'ARB', 'ARC', 'ARE', 'ARG', 'ARGX', 'ARH', 'ARI', 'ARJ', 'ARK', 'ARMF', 'ARSD', 'ART', 'ARV', 'ARW', 'ARX', 'ASA', 'ASBC', 'ASD', 'ASF', 'ASFC', 'ASG', 'ASGN', 'ASH', 'ASI', 'ASL', 'ASN', 'ASO', 'ASP', 'ASV', 'AT', 'ATC', 'ATEC', 'ATG', 'ATHM', 'ATI', 'ATK', 'ATL', 'ATO', 'ATR', 'ATS', 'ATV', 'ATW', 'ATY', 'AU', 'AUD', 'AVA', 'AVB', 'AVD', 'AVE', 'AVI', 'AVL', 'AVP', 'AVS', 'AVT', 'AVTR', 'AVX', 'AVY', 'AVZ', 'AW', 'AWA', 'AWC', 'AWF', 'AWG', 'AWK', 'AWR', 'AXA', 'AXE', 'AXF', 'AXL', 'AXM', 'AXP', 'AXR', 'AXT', 'AYE', 'AZA', 'AZN', 'AZO', 'AZR', 'AZUR', 'AZX', 'AZZ', 'B', 'BA', 'BAB', 'BAC', 'BALT', 'BANC', 'BAP', 'BAS', 'BAT', 'BAU', 'BAX', 'BB', 'BBA', 'BBAR', 'BBC', 'BBDC', 'BBI', 'BBR', 'BBT', 'BBV', 'BBX', 'BBY', 'BC', 'BCC', 'BCE', 'BCF', 'BCM', 'BCR', 'BCS', 'BCU', 'BD', 'BDE', 'BDF', 'BDG', 'BDK', 'BDL', 'BDN', 'BDX', 'BDY', 'BE', 'BEAM', 'BEC', 'BED', 'BEL', 'BEM', 'BEN', 'BEST', 'BETA', 'BEV', 'BEZ', 'BF', 'BFAM', 'BFC', 'BFCI', 'BFD', 'BFO', 'BFR', 'BFS', 'BFT', 'BGA', 'BGC', 'BGG', 'BGL', 'BGO', 'BGP', 'BGR', 'BGT', 'BGY', 'BH', 'BHC', 'BHE', 'BHI', 'BHP', 'BHW', 'BHY', 'BI', 'BID', 'BILL', 'BIN', 'BIO', 'BIOM', 'BIR', 'BJ', 'BJS', 'BK', 'BKC', 'BKE', 'BKF', 'BKH', 'BKI', 'BKLY', 'BKN', 'BKR', 'BKS', 'BKT', 'BLC', 'BLD', 'BLE', 'BLK', 'BLL', 'BLN', 'BLS', 'BLT', 'BLU', 'BLX', 'BMC', 'BMCS', 'BMG', 'BMHC', 'BMI', 'BMN', 'BMO', 'BMS', 'BMT', 'BMY', 'BN', 'BNA', 'BNE', 'BNG', 'BNI', 'BNO', 'BNS', 'BNT', 'BOA', 'BOG', 'BOH', 'BOL', 'BOOT', 'BOP', 'BOR', 'BOS', 'BOW', 'BOX', 'BOY', 'BPA', 'BPC', 'BPL', 'BPO', 'BPP', 'BPRX', 'BPT', 'BQT', 'BR', 'BRC', 'BRE', 'BRF', 'BRK', 'BRL', 'BRM', 'BRO', 'BRR', 'BRS', 'BRT', 'BRW', 'BRY', 'BS', 'BSB', 'BSC', 'BSD', 'BSH', 'BSI', 'BSP', 'BSTI', 'BSX', 'BSY', 'BSYS', 'BTF', 'BTH', 'BTI', 'BTM', 'BTN', 'BTO', 'BTR', 'BTT', 'BTY', 'BTZ', 'BUD', 'BUR', 'BVC', 'BVF', 'BVN', 'BW', 'BWA', 'BWC', 'BWE', 'BWG', 'BWP', 'BWS', 'BXG', 'BXL', 'BXM', 'BXP', 'BXS', 'BXT', 'BY', 'BYD', 'BYH', 'BZ', 'BZF', 'BZH', 'BZL', 'C', 'CA', 'CAA', 'CAB', 'CACI', 'CACOA', 'CADE', 'CAE', 'CAF', 'CAG', 'CAH', 'CAL', 'CAM', 'CAN', 'CANNY', 'CAO', 'CAP', 'CAR', 'CARL', 'CARN', 'CARS', 'CAS', 'CASC', 'CAT', 'CAV', 'CB', 'CBA', 'CBC', 'CBCL', 'CBE', 'CBG', 'CBH', 'CBI', 'CBIZ', 'CBK', 'CBL', 'CBLI', 'CBM', 'CBR', 'CBS', 'CBT', 'CBU', 'CBZ', 'CC', 'CCB', 'CCC', 'CCE', 'CCG', 'CCH', 'CCJ', 'CCK', 'CCL', 'CCN', 'CCOM', 'CCR', 'CCS', 'CCU', 'CD', 'CDA', 'CDB', 'CDC', 'CDCY', 'CDD', 'CDE', 'CDF', 'CDI', 'CDIS', 'CDL', 'CDN', 'CDO', 'CDP', 'CDT', 'CDX', 'CEA', 'CEC', 'CEE', 'CEFT', 'CEG', 'CEI', 'CEL', 'CEM', 'CEN', 'CF', 'CFA', 'CFB', 'CFCM', 'CFD', 'CFI', 'CFK', 'CFR', 'CFS', 'CFX', 'CG', 'CGA', 'CG ...
# Processed clustering for window ending 2000-02-10
# {'date': Timestamp('2000-02-10 00:00:00'), 'tickers': ['AA', 'AAC', 'AAG', 'AAIR', 'AAM', 'AAP', 'AAS', 'AAT', 'AB', 'ABERF', 'ABF', 'ABG', 'ABK', 'ABM', 'ABMD', 'ABN', 'ABP', 'ABR', 'ABRI', 'ABS', 'ABT', 'ABX', 'ABY', 'AC', 'ACEE', 'ACF', 'ACG', 'ACI', 'ACK', 'ACL', 'ACLNF', 'ACN', 'ACO', 'ACP', 'ACR', 'ACRG', 'ACS', 'ACTN', 'ACV', 'ACX', 'ACXM', 'AD', 'ADC', 'ADECY', 'ADF', 'ADG', 'ADI', 'ADM', 'ADMS', 'ADP', 'ADPT', 'ADV', 'ADX', 'AEC', 'AED', 'AEE', 'AEG', 'AEM', 'AEOS', 'AEP', 'AER', 'AES', 'AET', 'AF', 'AFC', 'AFF', 'AFG', 'AFL', 'AFM', 'AFP', 'AFS', 'AG', 'AGA', 'AGC', 'AGE', 'AGI', 'AGL', 'AGM', 'AGN', 'AGR', 'AGS', 'AGTX', 'AGU', 'AGX', 'AGY', 'AH', 'AHC', 'AHG', 'AHI', 'AHMH', 'AHO', 'AHP', 'AHR', 'AIB', 'AIC', 'AIF', 'AIG', 'AIN', 'AIR', 'AIV', 'AIZ', 'AJG', 'AJL', 'AJX', 'AK', 'AKO', 'AKR', 'AKS', 'AL', 'ALA', 'ALB', 'ALC', 'ALEX', 'ALG', 'ALK', 'ALL', 'ALLC', 'ALLE', 'ALLY', 'ALM', 'ALN', 'ALO', 'ALR', 'ALRE', 'ALS', 'ALU', 'ALV', 'ALX', 'AM', 'AMB', 'AMC', 'AMCR', 'AMD', 'AME', 'AMF', 'AMG', 'AMH', 'AMI', 'AMK', 'AML', 'AMN', 'AMO', 'AMR', 'AMSGA', 'AMT', 'AMTD', 'AMU', 'AMZ', 'AN', 'ANET', 'ANF', 'ANFI', 'ANH', 'ANN', 'ANS', 'ANZ', 'AOC', 'AOF', 'AOG', 'AOI', 'AOL', 'AOR', 'AOS', 'AP', 'APA', 'APB', 'APC', 'APCS', 'APD', 'APF', 'APGR', 'APH', 'APL', 'APO', 'APR', 'APS', 'APU', 'APW', 'APX', 'APZ', 'AQM', 'ARA', 'ARB', 'ARC', 'ARE', 'ARG', 'ARGX', 'ARH', 'ARI', 'ARJ', 'ARK', 'ARMF', 'ARSD', 'ART', 'ARV', 'ARW', 'ARX', 'ASA', 'ASBC', 'ASD', 'ASF', 'ASFC', 'ASG', 'ASGN', 'ASH', 'ASI', 'ASL', 'ASN', 'ASO', 'ASP', 'ASV', 'AT', 'ATC', 'ATEC', 'ATG', 'ATHM', 'ATI', 'ATK', 'ATL', 'ATO', 'ATR', 'ATS', 'ATV', 'ATW', 'ATY', 'AU', 'AUD', 'AVA', 'AVB', 'AVD', 'AVE', 'AVI', 'AVL', 'AVP', 'AVS', 'AVT', 'AVTR', 'AVX', 'AVY', 'AVZ', 'AW', 'AWA', 'AWC', 'AWF', 'AWG', 'AWK', 'AWR', 'AXA', 'AXE', 'AXF', 'AXL', 'AXM', 'AXP', 'AXR', 'AXT', 'AYE', 'AZA', 'AZN', 'AZO', 'AZR', 'AZUR', 'AZX', 'AZZ', 'B', 'BA', 'BAB', 'BAC', 'BALT', 'BANC', 'BAP', 'BAS', 'BAT', 'BAU', 'BAX', 'BB', 'BBA', 'BBAR', 'BBC', 'BBDC', 'BBI', 'BBR', 'BBT', 'BBV', 'BBX', 'BBY', 'BC', 'BCC', 'BCE', 'BCF', 'BCM', 'BCR', 'BCS', 'BCU', 'BD', 'BDE', 'BDF', 'BDG', 'BDK', 'BDL', 'BDN', 'BDX', 'BDY', 'BE', 'BEAM', 'BEC', 'BED', 'BEL', 'BEM', 'BEN', 'BEST', 'BETA', 'BEV', 'BEZ', 'BF', 'BFAM', 'BFC', 'BFCI', 'BFD', 'BFO', 'BFR', 'BFS', 'BFT', 'BGA', 'BGC', 'BGG', 'BGL', 'BGO', 'BGP', 'BGR', 'BGT', 'BGY', 'BH', 'BHC', 'BHE', 'BHI', 'BHP', 'BHW', 'BHY', 'BI', 'BID', 'BILL', 'BIN', 'BIO', 'BIOM', 'BIR', 'BJ', 'BJS', 'BK', 'BKC', 'BKE', 'BKF', 'BKH', 'BKI', 'BKLY', 'BKN', 'BKR', 'BKS', 'BKT', 'BLC', 'BLD', 'BLE', 'BLK', 'BLL', 'BLN', 'BLS', 'BLT', 'BLU', 'BLX', 'BMC', 'BMCS', 'BMG', 'BMHC', 'BMI', 'BMN', 'BMO', 'BMS', 'BMT', 'BMY', 'BN', 'BNA', 'BNE', 'BNG', 'BNI', 'BNO', 'BNS', 'BNT', 'BOA', 'BOG', 'BOH', 'BOL', 'BOOT', 'BOP', 'BOR', 'BOS', 'BOW', 'BOX', 'BOY', 'BPA', 'BPC', 'BPL', 'BPO', 'BPP', 'BPRX', 'BPT', 'BQT', 'BR', 'BRC', 'BRE', 'BRF', 'BRK', 'BRL', 'BRM', 'BRO', 'BRR', 'BRS', 'BRT', 'BRW', 'BRY', 'BS', 'BSB', 'BSC', 'BSD', 'BSH', 'BSI', 'BSP', 'BSTI', 'BSX', 'BSY', 'BSYS', 'BTF', 'BTH', 'BTI', 'BTM', 'BTN', 'BTO', 'BTR', 'BTT', 'BTY', 'BTZ', 'BUD', 'BUR', 'BVC', 'BVF', 'BVN', 'BW', 'BWA', 'BWC', 'BWE', 'BWG', 'BWP', 'BWS', 'BXG', 'BXL', 'BXM', 'BXP', 'BXS', 'BXT', 'BY', 'BYD', 'BYH', 'BZ', 'BZF', 'BZH', 'BZL', 'C', 'CA', 'CAA', 'CAB', 'CACI', 'CACOA', 'CADE', 'CAE', 'CAF', 'CAG', 'CAH', 'CAL', 'CAM', 'CAN', 'CANNY', 'CAO', 'CAP', 'CAR', 'CARL', 'CARN', 'CARS', 'CAS', 'CASC', 'CAT', 'CAV', 'CB', 'CBA', 'CBC', 'CBCL', 'CBE', 'CBG', 'CBH', 'CBI', 'CBIZ', 'CBK', 'CBL', 'CBLI', 'CBM', 'CBR', 'CBS', 'CBT', 'CBU', 'CBZ', 'CC', 'CCB', 'CCC', 'CCE', 'CCG', 'CCH', 'CCJ', 'CCK', 'CCL', 'CCN', 'CCOM', 'CCR', 'CCS', 'CCU', 'CD', 'CDA', 'CDB', 'CDC', 'CDCY', 'CDD', 'CDE', 'CDF', 'CDI', 'CDIS', 'CDL', 'CDN', 'CDO', 'CDP', 'CDT', 'CDX', 'CEA', 'CEC', 'CEE', 'CEFT', 'CEG', 'CEI', 'CEL', 'CEM', 'CEN', 'CF', 'CFA', 'CFB', 'CFCM', 'CFD', 'CFI', 'CFK', 'CFR', 'CFS', 'CFX', 'CG', 'CGA', 'CG ...
# Processed clustering for window ending 2000-02-11
# {'date': Timestamp('2000-02-11 00:00:00'), 'tickers': ['AA', 'AAC', 'AAG', 'AAIR', 'AAM', 'AAP', 'AAS', 'AAT', 'AB', 'ABERF', 'ABF', 'ABG', 'ABK', 'ABM', 'ABMD', 'ABN', 'ABP', 'ABR', 'ABRI', 'ABS', 'ABT', 'ABX', 'ABY', 'AC', 'ACEE', 'ACF', 'ACG', 'ACI', 'ACK', 'ACL', 'ACLNF', 'ACN', 'ACO', 'ACP', 'ACR', 'ACRG', 'ACS', 'ACTN', 'ACV', 'ACX', 'ACXM', 'AD', 'ADC', 'ADECY', 'ADF', 'ADG', 'ADI', 'ADM', 'ADMS', 'ADP', 'ADPT', 'ADV', 'ADX', 'AEC', 'AED', 'AEE', 'AEG', 'AEM', 'AEOS', 'AEP', 'AER', 'AES', 'AET', 'AF', 'AFC', 'AFF', 'AFG', 'AFL', 'AFM', 'AFP', 'AFS', 'AG', 'AGA', 'AGC', 'AGE', 'AGI', 'AGL', 'AGM', 'AGN', 'AGR', 'AGS', 'AGTX', 'AGU', 'AGX', 'AGY', 'AH', 'AHC', 'AHG', 'AHI', 'AHMH', 'AHO', 'AHP', 'AHR', 'AIB', 'AIC', 'AIF', 'AIG', 'AIN', 'AIR', 'AIV', 'AIZ', 'AJG', 'AJL', 'AJX', 'AK', 'AKO', 'AKR', 'AKS', 'AL', 'ALA', 'ALB', 'ALC', 'ALEX', 'ALG', 'ALK', 'ALL', 'ALLC', 'ALLE', 'ALLY', 'ALM', 'ALN', 'ALO', 'ALR', 'ALRE', 'ALS', 'ALU', 'ALV', 'ALX', 'AM', 'AMB', 'AMC', 'AMCR', 'AMD', 'AME', 'AMF', 'AMG', 'AMH', 'AMI', 'AMK', 'AML', 'AMN', 'AMO', 'AMR', 'AMSGA', 'AMT', 'AMTD', 'AMU', 'AMZ', 'AN', 'ANET', 'ANF', 'ANFI', 'ANH', 'ANN', 'ANS', 'ANZ', 'AOC', 'AOF', 'AOG', 'AOI', 'AOL', 'AOR', 'AOS', 'AP', 'APA', 'APB', 'APC', 'APCS', 'APD', 'APF', 'APGR', 'APH', 'APL', 'APO', 'APR', 'APS', 'APU', 'APW', 'APX', 'APZ', 'AQM', 'ARA', 'ARB', 'ARC', 'ARE', 'ARG', 'ARGX', 'ARH', 'ARI', 'ARJ', 'ARK', 'ARMF', 'ARSD', 'ART', 'ARV', 'ARW', 'ARX', 'ASA', 'ASBC', 'ASD', 'ASF', 'ASFC', 'ASG', 'ASGN', 'ASH', 'ASI', 'ASL', 'ASN', 'ASO', 'ASP', 'ASV', 'AT', 'ATC', 'ATEC', 'ATG', 'ATHM', 'ATI', 'ATK', 'ATL', 'ATO', 'ATR', 'ATS', 'ATV', 'ATW', 'ATY', 'AU', 'AUD', 'AVA', 'AVB', 'AVD', 'AVE', 'AVI', 'AVL', 'AVP', 'AVS', 'AVT', 'AVTR', 'AVX', 'AVY', 'AVZ', 'AW', 'AWA', 'AWC', 'AWF', 'AWG', 'AWK', 'AWR', 'AXA', 'AXE', 'AXF', 'AXL', 'AXM', 'AXP', 'AXR', 'AXT', 'AYE', 'AZA', 'AZN', 'AZO', 'AZR', 'AZUR', 'AZX', 'AZZ', 'B', 'BA', 'BAB', 'BAC', 'BALT', 'BANC', 'BAP', 'BAS', 'BAT', 'BAU', 'BAX', 'BB', 'BBA', 'BBAR', 'BBC', 'BBDC', 'BBI', 'BBR', 'BBT', 'BBV', 'BBX', 'BBY', 'BC', 'BCC', 'BCE', 'BCF', 'BCM', 'BCR', 'BCS', 'BCU', 'BD', 'BDE', 'BDF', 'BDG', 'BDK', 'BDL', 'BDN', 'BDX', 'BDY', 'BE', 'BEAM', 'BEC', 'BED', 'BEL', 'BEM', 'BEN', 'BEST', 'BETA', 'BEV', 'BEZ', 'BF', 'BFAM', 'BFC', 'BFCI', 'BFD', 'BFO', 'BFR', 'BFS', 'BFT', 'BGA', 'BGC', 'BGG', 'BGL', 'BGO', 'BGP', 'BGR', 'BGT', 'BGY', 'BH', 'BHC', 'BHE', 'BHI', 'BHP', 'BHW', 'BHY', 'BI', 'BID', 'BILL', 'BIN', 'BIO', 'BIOM', 'BIR', 'BJ', 'BJS', 'BK', 'BKC', 'BKE', 'BKF', 'BKH', 'BKI', 'BKLY', 'BKN', 'BKR', 'BKS', 'BKT', 'BLC', 'BLD', 'BLE', 'BLK', 'BLL', 'BLN', 'BLS', 'BLT', 'BLU', 'BLX', 'BMC', 'BMCS', 'BMG', 'BMHC', 'BMI', 'BMN', 'BMO', 'BMS', 'BMT', 'BMY', 'BN', 'BNA', 'BNE', 'BNG', 'BNI', 'BNL', 'BNO', 'BNS', 'BNT', 'BOA', 'BOG', 'BOH', 'BOL', 'BOOT', 'BOP', 'BOR', 'BOS', 'BOW', 'BOX', 'BOY', 'BPA', 'BPC', 'BPL', 'BPO', 'BPP', 'BPRX', 'BPT', 'BQT', 'BR', 'BRC', 'BRE', 'BRF', 'BRK', 'BRL', 'BRM', 'BRO', 'BRR', 'BRS', 'BRT', 'BRW', 'BRY', 'BS', 'BSB', 'BSC', 'BSD', 'BSH', 'BSI', 'BSP', 'BSTI', 'BSX', 'BSY', 'BSYS', 'BTF', 'BTH', 'BTI', 'BTM', 'BTN', 'BTO', 'BTR', 'BTT', 'BTY', 'BTZ', 'BUD', 'BUR', 'BVC', 'BVF', 'BVN', 'BW', 'BWA', 'BWC', 'BWE', 'BWG', 'BWP', 'BWS', 'BXG', 'BXL', 'BXM', 'BXP', 'BXS', 'BXT', 'BY', 'BYD', 'BYH', 'BZ', 'BZF', 'BZH', 'BZL', 'C', 'CA', 'CAA', 'CAB', 'CACI', 'CACOA', 'CADE', 'CAE', 'CAF', 'CAG', 'CAH', 'CAL', 'CAM', 'CAN', 'CANNY', 'CAO', 'CAP', 'CAR', 'CARL', 'CARN', 'CARS', 'CAS', 'CASC', 'CAT', 'CAV', 'CB', 'CBA', 'CBC', 'CBCL', 'CBE', 'CBG', 'CBH', 'CBI', 'CBIZ', 'CBK', 'CBL', 'CBLI', 'CBM', 'CBR', 'CBS', 'CBT', 'CBU', 'CBZ', 'CC', 'CCB', 'CCC', 'CCE', 'CCG', 'CCH', 'CCJ', 'CCK', 'CCL', 'CCN', 'CCOM', 'CCR', 'CCS', 'CCU', 'CD', 'CDA', 'CDB', 'CDC', 'CDCY', 'CDD', 'CDE', 'CDF', 'CDI', 'CDIS', 'CDL', 'CDN', 'CDO', 'CDP', 'CDT', 'CDX', 'CEA', 'CEC', 'CEE', 'CEFT', 'CEG', 'CEI', 'CEL', 'CEM', 'CEN', 'CF', 'CFA', 'CFB', 'CFCM', 'CFD', 'CFI', 'CFK', 'CFR', 'CFS', 'CFX', 'CG', 'CG ...
# Processed clustering for window ending 2000-02-14
# {'date': Timestamp('2000-02-14 00:00:00'), 'tickers': ['AA', 'AAC', 'AAG', 'AAIR', 'AAM', 'AAP', 'AAS', 'AAT', 'AB', 'ABERF', 'ABF', 'ABG', 'ABK', 'ABM', 'ABMD', 'ABN', 'ABP', 'ABR', 'ABRI', 'ABS', 'ABT', 'ABX', 'ABY', 'AC', 'ACEE', 'ACF', 'ACG', 'ACI', 'ACK', 'ACL', 'ACLNF', 'ACN', 'ACO', 'ACP', 'ACR', 'ACRG', 'ACS', 'ACTN', 'ACV', 'ACX', 'ACXM', 'AD', 'ADC', 'ADECY', 'ADF', 'ADG', 'ADI', 'ADM', 'ADMS', 'ADP', 'ADPT', 'ADV', 'ADX', 'AEC', 'AED', 'AEE', 'AEG', 'AEM', 'AEOS', 'AEP', 'AER', 'AES', 'AET', 'AF', 'AFC', 'AFF', 'AFG', 'AFL', 'AFM', 'AFP', 'AFS', 'AG', 'AGA', 'AGC', 'AGE', 'AGI', 'AGL', 'AGM', 'AGN', 'AGR', 'AGS', 'AGTX', 'AGU', 'AGX', 'AGY', 'AH', 'AHC', 'AHG', 'AHI', 'AHMH', 'AHO', 'AHP', 'AHR', 'AIB', 'AIC', 'AIF', 'AIG', 'AIN', 'AIR', 'AIV', 'AIZ', 'AJG', 'AJL', 'AJX', 'AK', 'AKO', 'AKR', 'AKS', 'AL', 'ALA', 'ALB', 'ALC', 'ALEX', 'ALG', 'ALK', 'ALL', 'ALLC', 'ALLE', 'ALLY', 'ALM', 'ALN', 'ALO', 'ALR', 'ALRE', 'ALS', 'ALU', 'ALV', 'ALX', 'AM', 'AMB', 'AMC', 'AMCR', 'AMD', 'AME', 'AMF', 'AMG', 'AMH', 'AMI', 'AMK', 'AML', 'AMN', 'AMO', 'AMR', 'AMSGA', 'AMT', 'AMTD', 'AMU', 'AMZ', 'AN', 'ANET', 'ANF', 'ANFI', 'ANH', 'ANN', 'ANS', 'ANZ', 'AOC', 'AOF', 'AOG', 'AOI', 'AOL', 'AOR', 'AOS', 'AP', 'APA', 'APB', 'APC', 'APCS', 'APD', 'APF', 'APGR', 'APH', 'APL', 'APO', 'APR', 'APS', 'APU', 'APW', 'APX', 'APZ', 'AQM', 'ARA', 'ARB', 'ARC', 'ARE', 'ARG', 'ARGX', 'ARH', 'ARI', 'ARJ', 'ARK', 'ARMF', 'ARSD', 'ART', 'ARV', 'ARW', 'ARX', 'ASA', 'ASBC', 'ASD', 'ASF', 'ASFC', 'ASG', 'ASGN', 'ASH', 'ASI', 'ASL', 'ASN', 'ASO', 'ASP', 'ASV', 'AT', 'ATC', 'ATEC', 'ATG', 'ATHM', 'ATI', 'ATK', 'ATL', 'ATO', 'ATR', 'ATS', 'ATV', 'ATW', 'ATY', 'AU', 'AUD', 'AVA', 'AVB', 'AVD', 'AVE', 'AVI', 'AVL', 'AVP', 'AVS', 'AVT', 'AVTR', 'AVX', 'AVY', 'AVZ', 'AW', 'AWA', 'AWC', 'AWF', 'AWG', 'AWK', 'AWR', 'AXA', 'AXE', 'AXF', 'AXL', 'AXM', 'AXP', 'AXR', 'AXT', 'AYE', 'AZA', 'AZN', 'AZO', 'AZR', 'AZUR', 'AZX', 'AZZ', 'B', 'BA', 'BAB', 'BAC', 'BALT', 'BANC', 'BAP', 'BAS', 'BAT', 'BAU', 'BAX', 'BB', 'BBA', 'BBAR', 'BBC', 'BBDC', 'BBI', 'BBR', 'BBT', 'BBV', 'BBX', 'BBY', 'BC', 'BCC', 'BCE', 'BCF', 'BCM', 'BCR', 'BCS', 'BCU', 'BD', 'BDE', 'BDF', 'BDG', 'BDK', 'BDL', 'BDN', 'BDX', 'BDY', 'BE', 'BEAM', 'BEC', 'BED', 'BEL', 'BEM', 'BEN', 'BEST', 'BETA', 'BEV', 'BEZ', 'BF', 'BFAM', 'BFC', 'BFCI', 'BFD', 'BFO', 'BFR', 'BFS', 'BFT', 'BGA', 'BGC', 'BGG', 'BGL', 'BGO', 'BGP', 'BGR', 'BGT', 'BGY', 'BH', 'BHC', 'BHE', 'BHI', 'BHP', 'BHW', 'BHY', 'BI', 'BID', 'BILL', 'BIN', 'BIO', 'BIOM', 'BIR', 'BJ', 'BJS', 'BK', 'BKC', 'BKE', 'BKF', 'BKH', 'BKI', 'BKLY', 'BKN', 'BKR', 'BKS', 'BKT', 'BLC', 'BLD', 'BLE', 'BLK', 'BLL', 'BLN', 'BLS', 'BLT', 'BLU', 'BLX', 'BMC', 'BMCS', 'BMG', 'BMHC', 'BMI', 'BMN', 'BMO', 'BMS', 'BMT', 'BMY', 'BN', 'BNA', 'BNE', 'BNG', 'BNI', 'BNL', 'BNO', 'BNS', 'BNT', 'BOA', 'BOG', 'BOH', 'BOL', 'BOOT', 'BOP', 'BOR', 'BOS', 'BOW', 'BOX', 'BOY', 'BPA', 'BPC', 'BPL', 'BPO', 'BPP', 'BPRX', 'BPT', 'BQT', 'BR', 'BRC', 'BRE', 'BRF', 'BRK', 'BRL', 'BRM', 'BRO', 'BRR', 'BRS', 'BRT', 'BRW', 'BRY', 'BS', 'BSB', 'BSC', 'BSD', 'BSH', 'BSI', 'BSP', 'BSTI', 'BSX', 'BSY', 'BSYS', 'BTF', 'BTH', 'BTI', 'BTM', 'BTN', 'BTO', 'BTR', 'BTT', 'BTY', 'BTZ', 'BUD', 'BUR', 'BVC', 'BVF', 'BVN', 'BW', 'BWA', 'BWC', 'BWE', 'BWG', 'BWP', 'BWS', 'BXG', 'BXL', 'BXM', 'BXP', 'BXS', 'BXT', 'BY', 'BYD', 'BYH', 'BZ', 'BZF', 'BZH', 'BZL', 'C', 'CA', 'CAA', 'CAB', 'CACI', 'CACOA', 'CADE', 'CAE', 'CAF', 'CAG', 'CAH', 'CAL', 'CAM', 'CAN', 'CANNY', 'CAO', 'CAP', 'CAR', 'CARL', 'CARN', 'CARS', 'CAS', 'CASC', 'CAT', 'CAV', 'CB', 'CBA', 'CBC', 'CBCL', 'CBE', 'CBG', 'CBH', 'CBI', 'CBIZ', 'CBK', 'CBL', 'CBLI', 'CBM', 'CBR', 'CBS', 'CBT', 'CBU', 'CBZ', 'CC', 'CCB', 'CCC', 'CCE', 'CCG', 'CCH', 'CCJ', 'CCK', 'CCL', 'CCN', 'CCOM', 'CCR', 'CCS', 'CCU', 'CD', 'CDA', 'CDB', 'CDC', 'CDCY', 'CDD', 'CDE', 'CDF', 'CDI', 'CDIS', 'CDL', 'CDN', 'CDO', 'CDP', 'CDT', 'CDX', 'CEA', 'CEC', 'CEE', 'CEFT', 'CEG', 'CEI', 'CEL', 'CEM', 'CEN', 'CF', 'CFA', 'CFB', 'CFCM', 'CFD', 'CFI', 'CFK', 'CFR', 'CFS', 'CFX', 'CG', 'CG ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb Cell 14 line 2
#       <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> #df = your_loaded_dataframe_with_all_data
# ----> <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> results = run_rolling_sponge_clustering(df, lookback=20, threshold=0.3, k=5)
#
# /Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb Cell 14 line 1
#      <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X35sZmlsZQ%3D%3D?line=12'>13</a>     continue
#      <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X35sZmlsZQ%3D%3D?line=14'>15</a> Ap, An = build_signed_graph(R, threshold=threshold)
# ---> <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X35sZmlsZQ%3D%3D?line=15'>16</a> labels = sponge_clustering(Ap, An, k=k)
#      <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X35sZmlsZQ%3D%3D?line=17'>18</a> results.append({
#      <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X35sZmlsZQ%3D%3D?line=18'>19</a>     'date': unique_dates[i],
#      <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X35sZmlsZQ%3D%3D?line=19'>20</a>     'tickers': R.index.tolist(),
#      <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X35sZmlsZQ%3D%3D?line=20'>21</a>     'labels': labels
#      <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X35sZmlsZQ%3D%3D?line=21'>22</a> })
#      <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X35sZmlsZQ%3D%3D?line=22'>23</a> print(f"Processed clustering for window ending {unique_dates[i].date()}")
#
# /Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb Cell 14 line 6
#       <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> """
#       <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> Perform SPONGE clustering on signed graph defined by (Ap, An)
#       <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a> """
#       <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X35sZmlsZQ%3D%3D?line=4'>5</a> clusterer = Cluster((Ap, An))
# ----> <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X35sZmlsZQ%3D%3D?line=5'>6</a> labels = clusterer.SPONGE(k=k, tau_p=tau_p, tau_n=tau_n)
#       <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X35sZmlsZQ%3D%3D?line=6'>7</a> return labels
#
# File /usr/local/lib/python3.9/site-packages/signet/cluster.py:525, in Cluster.SPONGE(self, k, tau_p, tau_n, eigens, mi)
#     522 matrix2 = matrix2 + tau_p * self.D_p
#     524 v0 = np.random.normal(0, 1, (self.p.shape[0], eigens))
# --> 525 (w, v) = ss.linalg.lobpcg(matrix1, v0, B=matrix2, maxiter=mi, largest=False)
#     527 v = v / w
#     528 if not listk:
#
# File /usr/local/lib/python3.9/site-packages/scipy/sparse/linalg/_eigen/lobpcg/lobpcg.py:791, in lobpcg(A, X, B, M, Y, tol, maxiter, largest, verbosityLevel, retLambdaHistory, retResidualNormsHistory, restartControl)
#     784     warnings.warn(
#     785         f"Failed at iteration {iterationNumber} with accuracies "
#     786         f"{residualNorms}\n not reaching the requested "
#     787         f"tolerance {residualTolerance}.",
#     788         UserWarning, stacklevel=2
#     789     )
#     790     break
# --> 791 activeBlockVectorAR = A(activeBlockVectorR)
#     793 if iterationNumber > 0:
#     794     if B is not None:
#
# File /usr/local/lib/python3.9/site-packages/scipy/sparse/linalg/_eigen/lobpcg/lobpcg.py:66, in _makeMatMat.<locals>.<lambda>(v)
#      64     return lambda v: m(v)
#      65 else:
# ---> 66     return lambda v: m @ v
#
# File /usr/local/lib/python3.9/site-packages/scipy/sparse/_base.py:695, in _spbase.__matmul__(self, other)
#     692 if isscalarlike(other):
#     693     raise ValueError("Scalar operands are not allowed, "
#     694                      "use '*' instead")
# --> 695 return self._matmul_dispatch(other)
#
# File /usr/local/lib/python3.9/site-packages/scipy/sparse/_base.py:590, in _spbase._matmul_dispatch(self, other)
#     588     return self._matmul_vector(other)
#     589 elif other.shape == (N, 1):
# --> 590     result = self._matmul_vector(other.ravel())
#     591     if self.ndim == 1:
#     592         return result
#
# File /usr/local/lib/python3.9/site-packages/scipy/sparse/_compressed.py:491, in _cs_matrix._matmul_vector(self, other)
#     489 # csr_matvec or csc_matvec
#     490 fn = getattr(_sparsetools, self.format + '_matvec')
# --> 491 fn(M, N, self.indptr, self.indices, self.data, other, result)
#     493 return result
#
# KeyboardInterrupt:

# %%
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/Users/jackmauro/Documents/GitHub/leadlagClustering/clusteringDev.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> results
#
# NameError: name 'results' is not defined
